# %%
import numpy as np
import pandas as pd

import os
import sys

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[['embark_town', 'alive']]
# Out:
#      embark_town alive
# 0    Southampton    no
# 1      Cherbourg   yes
# 2    Southampton   yes
# 3    Southampton   yes
# 4    Southampton    no
# ..           ...   ...
# 886  Southampton    no
# 887  Southampton   yes
# 888  Southampton    no
# 889    Cherbourg   yes
# 890   Queenstown    no
#
# [891 rows x 2 columns]

# %%
set([str(x) for x in zip(df['embark_town'], df['alive'])])
# Out:
# {"('Cherbourg', 'no')",
#  "('Cherbourg', 'yes')",
#  "('Queenstown', 'no')",
#  "('Queenstown', 'yes')",
#  "('Southampton', 'no')",
#  "('Southampton', 'yes')",
#  "(nan, 'yes')"}

# %%
pd.DataFrame(df[['sex', 'alive']].groupby(by=['sex', 'alive'])['sex'].count())
# Out:
#               sex
# sex    alive
# female no      81
#        yes    233
# male   no     468
#        yes    109

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df["fare_15"] = df["fare"] >= 15.0

# %%
df[df["adult_male"] == False].shape
# Out:
# (354, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  fare_15      891 non-null    bool
# dtypes: bool(3), float64(2), int64(4), object(7)
# memory usage: 93.2+ KB

# %%
help(df.info)
# Out:
# Help on method info in module pandas.core.frame:
#
# info(verbose: 'bool | None' = None, buf: 'WriteBuffer[str] | None' = None, max_cols: 'int | None' = None, memory_usage: 'bool | str | None' = None, show_counts: 'bool | None' = None) -> 'None' method of pandas.core.frame.DataFrame instance
#     Print a concise summary of a DataFrame.
#
#     This method prints information about a DataFrame including
#     the index dtype and columns, non-null values and memory usage.
#
#     Parameters
#     ----------
#     verbose : bool, optional
#         Whether to print the full summary. By default, the setting in
#         ``pandas.options.display.max_info_columns`` is followed.
#     buf : writable buffer, defaults to sys.stdout
#         Where to send the output. By default, the output is printed to
#         sys.stdout. Pass a writable buffer if you need to further process
#         the output.
#     max_cols : int, optional
# ...

# %%
df[df["age"].notna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     714 non-null    int64
#  1   pclass       714 non-null    int64
#  2   sex          714 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        714 non-null    int64
#  5   parch        714 non-null    int64
#  6   fare         714 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        714 non-null    object
#  9   who          714 non-null    object
#  10  adult_male   714 non-null    bool
#  11  deck         184 non-null    object
#  12  embark_town  712 non-null    object
#  13  alive        714 non-null    object
#  14  alone        714 non-null    bool
#  15  fare_15      714 non-null    bool
# dtypes: bool(3), float64(2), int64(4), object(7)
# memory usage: 80.2+ KB

# %%
df.loc[df["age"] > 35, ["sex", "age"]]
# Out:
#         sex   age
# 1    female  38.0
# 6      male  54.0
# 11   female  58.0
# 13     male  39.0
# 15   female  55.0
# ..      ...   ...
# 865  female  42.0
# 871  female  47.0
# 873    male  47.0
# 879  female  56.0
# 885  female  39.0
#
# [217 rows x 2 columns]

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.iloc[0:100, 0:4]
# Out:
#     survived  pclass     sex   age
# 0          0       3    male  22.0
# 1          1       1  female  38.0
# 2          1       3  female  26.0
# 3          1       1  female  35.0
# 4          0       3    male  35.0
# ..       ...     ...     ...   ...
# 95         0       3    male   NaN
# 96         0       1    male  71.0
# 97         1       1    male  23.0
# 98         1       2  female  34.0
# 99         0       2    male  34.0
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df.plot.scatter(x="age", y="fare")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
plt.show()

# %%
df.plot.area(figsize=(12, 8), subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df["third_class"] = (df["class"] == "Third")

# %%
df[df["third_class"]]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 5           0       3    male   NaN      0      0   8.4583        Q  Third
# 7           0       3    male   2.0      3      1  21.0750        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 882         0       3  female  22.0      0      0  10.5167        S  Third
# 884         0       3    male  25.0      0      0   7.0500        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
# ...

# %%
df["fare_age"] = (df["fare"] * df["age"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  fare_15      891 non-null    bool
#  16  third_class  891 non-null    bool
#  17  fare_age     714 non-null    float64
# ...

# %%
df[["age", "sex"]].groupby("sex").count()
# Out:
#         age
# sex
# female  261
# male    453

# %%
df.groupby("alive")["fare"].mean(numeric_only=True)
# Out:
# alive
# no     22.117887
# yes    48.395408
# Name: fare, dtype: float64

# %%
df.groupby(["alive", "sex", "who"])["fare"].mean(numeric_only=True)
# Out:
# alive  sex     who
# no     female  child    32.076113
#                woman    20.967174
#        male    child    33.073905
#                man      21.490736
# yes    female  child    30.887800
#                woman    54.813801
#        male    child    35.562700
#                man      42.076422
# Name: fare, dtype: float64

# %%
poke = pd.read_csv("poke800.csv")

# %%
poke
# Out:
#       id        name  height  weight  \
# 0      1   bulbasaur       7      69
# 1      2     ivysaur      10     130
# 2      3    venusaur      20    1000
# 3      4  charmander       6      85
# 4      5  charmeleon      11     190
# ..   ...         ...     ...     ...
# 795  796   xurkitree      38    1000
# 796  797  celesteela      92    9999
# 797  798     kartana       3       1
# 798  799    guzzlord      55    8880
# 799  800    necrozma      24    2300
#
#                                                   lang  \
# 0    [['フシギダネ', 'ja-Hrkt'], ['Fushigidane', 'roomaj...
# 1    [['フシギソウ', 'ja-Hrkt'], ['Fushigisou', 'roomaji...
# 2    [['フシギバナ', 'ja-Hrkt'], ['Fushigibana', 'roomaj...
# 3    [['ヒトカゲ', 'ja-Hrkt'], ['Hitokage', 'roomaji'],...
# 4    [['リザード', 'ja-Hrkt'], ['Lizardo', 'roomaji'], ...
# ..                                                 ...
# 795  [['デンジュモク', 'ja-Hrkt'], ['Denjyumoku', 'roomaj...
# 796  [['テッカグヤ', 'ja-Hrkt'], ['Tekkaguya', 'roomaji'...
# ...

# %%
poke.plot.scatter(x="height", y="weight")

for i, txt in enumerate(poke["name"]):
    plt.annotate(txt, (poke["height"].iloc[i], poke["weight"].iloc[i]))
